# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
layoff = pd.read_csv(r"C:\Users\Patience\Desktop\Data\layoff.csv")

# %%
layoff
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail             NaN
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %%
layoff.head()
# Out:
#      company       location     industry  total_laid_off  percentage_laid_off  \
# 0  Atlassian         Sydney        Other           500.0                 0.05
# 1   SiriusXM  New York City        Media           475.0                 0.08
# 2     Alerzo         Ibadan       Retail           400.0                  NaN
# 3     UpGrad         Mumbai    Education           120.0                  NaN
# 4       Loft      Sao Paulo  Real Estate           340.0                 0.15
#
#        date     stage        country  funds_raised_millions
# 0  3/6/2023  Post-IPO      Australia                  210.0
# 1  3/6/2023  Post-IPO  United States                  525.0
# 2  3/6/2023  Series B        Nigeria                   16.0
# 3  3/6/2023   Unknown          India                  631.0
# 4  3/3/2023   Unknown         Brazil                  788.0

# %%
layoff.tail()
# Out:
#                company       location  industry  total_laid_off  \
# 2356         Blackbaud     Charleston     Other           500.0
# 2357             Yahoo    SF Bay Area  Consumer          1600.0
# 2358             Hibob       Tel Aviv        HR            70.0
# 2359            Casper  New York City    Retail             NaN
# 2360  Wildlife Studios      Sao Paulo  Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 2356                 0.14         NaN  Post-IPO  United States
# 2357                 0.20    2/9/2023  Acquired  United States
# 2358                 0.30   3/30/2020  Series A         Israel
# 2359                  NaN   9/14/2021  Post-IPO  United States
# 2360                 0.20  11/28/2022   Unknown         Brazil
#
#       funds_raised_millions
# 2356                    NaN
# 2357                    6.0
# 2358                   45.0
# 2359                  339.0
# 2360                  260.0

# %% [markdown]
# # Exploratory Data Analysis

# %%
layoff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company                2361 non-null   object
#  1   location               2361 non-null   object
#  2   industry               2357 non-null   object
#  3   total_laid_off         1621 non-null   float64
#  4   percentage_laid_off    1576 non-null   float64
#  5   date                   2360 non-null   object
#  6   stage                  2355 non-null   object
#  7   country                2361 non-null   object
#  8   funds_raised_millions  2152 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 166.1+ KB

# %%
layoff.shape
# Out:
# (2361, 9)

# %%
layoff.isnull().sum()
# Out:
# company                    0
# location                   0
# industry                   4
# total_laid_off           740
# percentage_laid_off      785
# date                       1
# stage                      6
# country                    0
# funds_raised_millions    209
# dtype: int64

# %%
layoff.total_laid_off.describe()
# Out:
# count     1621.000000
# mean       238.358421
# std        769.718801
# min          3.000000
# 25%         36.000000
# 50%         80.000000
# 75%        180.000000
# max      12000.000000
# Name: total_laid_off, dtype: float64

# %%
layoff['total_laid_off']
# Out:
# 0        500.0
# 1        475.0
# 2        400.0
# 3        120.0
# 4        340.0
#          ...
# 2356     500.0
# 2357    1600.0
# 2358      70.0
# 2359       NaN
# 2360     300.0
# Name: total_laid_off, Length: 2361, dtype: float64

# %%
layoff['total_laid_off'].unique()
# Out:
# array([5.000e+02, 4.750e+02, 4.000e+02, 1.200e+02, 3.400e+02, 2.300e+02,
#        1.000e+02, 6.300e+01, 3.000e+01,       nan, 1.770e+02, 7.900e+01,
#        5.000e+01, 1.200e+01, 3.550e+02, 3.000e+02, 2.090e+02, 2.000e+02,
#        8.000e+01, 2.850e+02, 1.300e+02, 7.500e+01, 7.000e+01, 1.900e+01,
#        4.000e+01, 8.500e+03, 2.200e+02, 5.900e+01, 2.600e+01, 2.400e+01,
#        1.500e+02, 6.900e+01, 1.860e+02, 8.500e+01, 1.700e+01, 8.000e+00,
#        1.290e+02, 6.800e+02, 3.700e+02, 2.210e+02, 2.100e+02, 2.080e+02,
#        2.800e+01, 3.710e+02, 1.500e+03, 1.410e+02, 9.400e+01, 5.400e+01,
#        2.200e+01, 3.600e+02, 1.600e+03, 6.490e+02, 3.500e+02, 2.150e+02,
#        1.550e+02, 1.260e+02, 1.190e+02, 6.600e+01, 3.100e+01, 5.300e+02,
#        1.300e+03, 2.120e+02, 8.300e+01, 2.700e+01, 6.650e+03, 2.000e+01,
#        9.000e+01, 8.900e+01, 2.500e+02, 1.270e+02, 1.250e+02, 3.800e+01,
#        3.250e+02, 1.400e+02, 1.210e+02, 6.000e+01, 5.600e+01, 4.400e+01,
# ...

# %%
layoff['total_laid_off'].nunique()
# Out:
# 285

# %%
layoff['total_laid_off'].value_counts()
# Out:
# 100.0     97
# 30.0      71
# 40.0      60
# 50.0      55
# 200.0     50
#           ..
# 251.0      1
# 186.0      1
# 158.0      1
# 1250.0     1
# 375.0      1
# Name: total_laid_off, Length: 285, dtype: int64

# %%
layoff.total_laid_off.median()
# Out:
# 80.0

# %%
layoff['total_laid_off'].fillna(layoff.total_laid_off.median(), inplace = True)

# %%
layoff
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail            80.0
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 0                    0.05    3/6/2023  Post-IPO      Australia
# ...

# %%
layoff.total_laid_off.isnull().sum()
# Out:
# 0

# %%
layoff.percentage_laid_off.describe()
# Out:
# count    1576.000000
# mean        0.257917
# std         0.255575
# min         0.000000
# 25%         0.100000
# 50%         0.170000
# 75%         0.300000
# max         1.000000
# Name: percentage_laid_off, dtype: float64

# %%
layoff.percentage_laid_off.mean()
# Out:
# 0.25791719543147207

# %%
layoff.fillna(layoff.percentage_laid_off.mean(), inplace = True)

# %%
layoff.percentage_laid_off.isnull().sum()
# Out:
# 0

# %%
layoff.isnull().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off           0
# percentage_laid_off      0
# date                     0
# stage                    0
# country                  0
# funds_raised_millions    0
# dtype: int64

# %%
layoff.date.isnull().sum()
# Out:
# 0

# %%
layoff.dtypes
# Out:
# company                   object
# location                  object
# industry                  object
# total_laid_off           float64
# percentage_laid_off      float64
# date                      object
# stage                     object
# country                   object
# funds_raised_millions    float64
# dtype: object

# %%
layoff['date'] = pd.to_datetime(layoff['date'])

# %%
layoff
# Out:
#                company       location     industry  total_laid_off  \
# 0            Atlassian         Sydney        Other           500.0
# 1             SiriusXM  New York City        Media           475.0
# 2               Alerzo         Ibadan       Retail           400.0
# 3               UpGrad         Mumbai    Education           120.0
# 4                 Loft      Sao Paulo  Real Estate           340.0
# ...                ...            ...          ...             ...
# 2356         Blackbaud     Charleston        Other           500.0
# 2357             Yahoo    SF Bay Area     Consumer          1600.0
# 2358             Hibob       Tel Aviv           HR            70.0
# 2359            Casper  New York City       Retail            80.0
# 2360  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#       percentage_laid_off       date     stage        country  \
# 0                0.050000 2023-03-06  Post-IPO      Australia
# ...

# %%
layoff.set_index('date', inplace=True)

# %%
layoff
# Out:
#                      company       location     industry  total_laid_off  \
# date
# 2023-03-06         Atlassian         Sydney        Other           500.0
# 2023-03-06          SiriusXM  New York City        Media           475.0
# 2023-03-06            Alerzo         Ibadan       Retail           400.0
# 2023-03-06            UpGrad         Mumbai    Education           120.0
# 2023-03-03              Loft      Sao Paulo  Real Estate           340.0
# ...                      ...            ...          ...             ...
# 1970-01-01         Blackbaud     Charleston        Other           500.0
# 2023-02-09             Yahoo    SF Bay Area     Consumer          1600.0
# 2020-03-30             Hibob       Tel Aviv           HR            70.0
# 2021-09-14            Casper  New York City       Retail            80.0
# 2022-11-28  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#             percentage_laid_off     stage        country  \
# date
# ...

# %%
layoff.isnull().sum()
# Out:
# company                  0
# location                 0
# industry                 0
# total_laid_off           0
# percentage_laid_off      0
# stage                    0
# country                  0
# funds_raised_millions    0
# dtype: int64

# %%
layoff
# Out:
#                      company       location     industry  total_laid_off  \
# date
# 2023-03-06         Atlassian         Sydney        Other           500.0
# 2023-03-06          SiriusXM  New York City        Media           475.0
# 2023-03-06            Alerzo         Ibadan       Retail           400.0
# 2023-03-06            UpGrad         Mumbai    Education           120.0
# 2023-03-03              Loft      Sao Paulo  Real Estate           340.0
# ...                      ...            ...          ...             ...
# 1970-01-01         Blackbaud     Charleston        Other           500.0
# 2023-02-09             Yahoo    SF Bay Area     Consumer          1600.0
# 2020-03-30             Hibob       Tel Aviv           HR            70.0
# 2021-09-14            Casper  New York City       Retail            80.0
# 2022-11-28  Wildlife Studios      Sao Paulo     Consumer           300.0
#
#             percentage_laid_off     stage        country  \
# date
# ...

# %%
layoff.duplicated()
# Out:
# date
# 2023-03-06    False
# 2023-03-06    False
# 2023-03-06    False
# 2023-03-06    False
# 2023-03-03    False
#               ...
# 1970-01-01    False
# 2023-02-09     True
# 2020-03-30     True
# 2021-09-14     True
# 2022-11-28     True
# Length: 2361, dtype: bool

# %%
layoff.drop_duplicates(inplace = True)

# %%
layoff.shape
# Out:
# (2340, 8)

# %%
total_laid = layoff.total_laid_off.sum()

# %%
total_laid
# Out:
# 441400.0

# %%
total_laid_percentage= layoff.percentage_laid_off.sum()

# %%
total_laid_percentage
# Out:
# 603.7458232868021

# %%
total_fund_raised = layoff.funds_raised_millions.sum()

# %%
total_fund_raised
# Out:
# 1756053.426442259

# %% [markdown]
# # Data Visualization

# %%
# Top 5 companies by Percentage_laid_off
company_percentage_layoff = layoff.groupby('company')['percentage_laid_off'].sum().reset_index()
top_5_company = company_percentage_layoff.sort_values(by='percentage_laid_off', ascending=False).head(5)
top_5_company.set_index('company')['percentage_laid_off'].plot(kind='pie', autopct='%1.1f%%', shadow = True, explode = (0,0,0,0,0.1))
plt.title('Top 5 Companies by Percentage of Layoffs')
plt.show()

# %%
#Top 10 countries by total_laid_off
countries_total_layoff = layoff.groupby('country')['total_laid_off'].sum()
top_10_countries = countries_total_layoff.sort_values(ascending=False).head(10)
top_10_countries.plot(kind='bar')
plt.title('Top 10 Countries by Total Layoffs')
plt.ylabel('total_laid_off')
plt.xlabel('country')
plt.show()

# %%
# Total numbers of each industry
layoff.industry.value_counts()
# Out:
# Finance                284
# Retail                 193
# Healthcare             180
# Transportation         146
# Food                   140
# Marketing              139
# Other                  126
# Real Estate            116
# Consumer               115
# Crypto                  99
# Media                   94
# Education               93
# Data                    79
# Security                73
# Travel                  66
# HR                      64
# Infrastructure          43
# Support                 42
# Logistics               42
# Sales                   37
# Product                 35
# Fitness                 30
# Recruiting              28
# Hardware                17
# Construction            16
# Legal                   13
# Energy                  12
# Aerospace                6
# 0.25791719543147207      4
# Fin-Tech                 3
# Manufacturing            2
# Crypto Currency          2
# CryptoCurrency           1
# Name: industry, dtype: int64

# %%
# Display the industry 
layoff['industry'].value_counts().plot(kind='bar',figsize=(10,6))
plt.xlabel('Industry')
plt.ylabel('Total_laid_off')
plt.title('Total laid off per industry')
plt.legend()

# %%
layoff
# Out:
#                   company        location        industry  total_laid_off  \
# date
# 2023-03-06      Atlassian          Sydney           Other           500.0
# 2023-03-06       SiriusXM   New York City           Media           475.0
# 2023-03-06         Alerzo          Ibadan          Retail           400.0
# 2023-03-06         UpGrad          Mumbai       Education           120.0
# 2023-03-03           Loft       Sao Paulo     Real Estate           340.0
# ...                   ...             ...             ...             ...
# 2020-03-13   HopSkipDrive     Los Angeles  Transportation             8.0
# 2020-03-13    Panda Squad     SF Bay Area        Consumer             6.0
# 2020-03-12  Tamara Mellon     Los Angeles          Retail            20.0
# 2020-03-11       EasyPost  Salt Lake City       Logistics            75.0
# 1970-01-01      Blackbaud      Charleston           Other           500.0
#
#             percentage_laid_off     stage        country  \
# date
# ...

# %%
#top 10 countries by fund_raised_million
countries_fund_raised = layoff.groupby('country')['funds_raised_millions'].sum()
top_10_countries = countries_fund_raised.sort_values(ascending=False).head(10)
top_10_countries.plot(kind='bar' , color = 'green')
plt.title('Top 10 Countries by fund_raised_million')
plt.ylabel('fund_raised_million')
plt.xlabel('country')
plt.show()
